# %% [markdown]
# ## Begin with Python  😎

# %% [markdown]
# #### ![image.png](attachment:image.png)

# %%
strng = ("I am learning python")

# %%
strng
# Out:
# 'I am learning python'

# %%
len(strng)
# Out:
# 20

# %%
# length is 20 coz it includes space also 🤓

# %%
strng[len(strng)-1]
# Out:
# 'n'

# %%
# it gives the digit from the last as it donates "-"  😌

# %%
strng[-2]
# Out:
# 'o'

# %%
strng[-3]
# Out:
# 'h'

# %%
strng[-4]
# Out:
# 't'

# %%
strng[-7]
# Out:
# ' '

# %%
strng[0:2]
# Out:
# 'I '

# %%
# it includes the digit starting from 0 and it will only count the digit between 0-1-2 so the output will be 1

# %%
# also (x:y) where x is row y is column  👻

# %%
strng[ :4]
# Out:
# 'I am'

# %%
strng[5: ]
# Out:
# 'learning python'

# %%
strng[ : ]
# Out:
# 'I am learning python'

# %%
# adding two strings  🤩

# %%
a = "all is well"

# %%
a
# Out:
# 'all is well'

# %%
b="A"+a[1: ]

# %%
b
# Out:
# 'All is well'

# %%
# a in all is replaced by "A"  🤩

# %%
len(a)
# Out:
# 11

# %%
len(b)
# Out:
# 11

# %%
mytuple = (7, 'Lucky','Excellent', 5.5)

# %%
print(type(mytuple))
# Out:
# <class 'tuple'>

# %%
mytuple
# Out:
# (7, 'Lucky', 'Excellent', 5.5)

# %%
# all the words & numbers considered as one, not numbered individually as in string & spaces are also not included.

# %%
# it starts with 0 and so on... as 7 is 0 lucky is 1 (tuple is a set of values)

# %%
len(mytuple)
# Out:
# 4

# %%
mytuple[0]
# Out:
# 7

# %%
mytuple[1]
# Out:
# 'Lucky'

# %%
mytuple[3]
# Out:
# 5.5

# %%
mytuple[-1]
# Out:
# 5.5

# %%
mytuple[-3]
# Out:
# 'Lucky'

# %%
mytuple[0:2]
# Out:
# (7, 'Lucky')

# %%
mytuple+=("Wonderful", )

# %%
mytuple
# Out:
# (7, 'Lucky', 'Excellent', 5.5, 'Wonderful')

# %%
# always put comma after the new word to be added

# %%
tuple1=(11,33,22,44,55)

# %%
tuple1
# Out:
# (11, 33, 22, 44, 55)

# %%
tuple2= sorted(tuple1)

# %%
# arrange in ascending order

# %%
tuple2
# Out:
# [11, 22, 33, 44, 55]

# %%
isinstance(tuple1, tuple)
# Out:
# True

# %%
isinstance(tuple2, tuple)
# Out:
# False

# %%
isinstance(tuple2, list)
# Out:
# True

# %%
# integer vs tuple

# %%
a=4

# %%
a
# Out:
# 4

# %%
b=(4, )

# %%
b
# Out:
# (4,)

# %%
# string vs tuple

# %%
a="Hello World! "

# %%
a
# Out:
# 'Hello World! '

# %%
a=( "Hello World!" )

# %%
isinstance (a, tuple)
# Out:
# False

# %%
a
# Out:
# 'Hello World!'

# %%
a=("Hello World! ", "Hi" )

# %%
a
# Out:
# ('Hello World! ', 'Hi')

# %%
isinstance(a, tuple)
# Out:
# True

# %%
b=("Hello World! ", )

# %%
b
# Out:
# ('Hello World! ',)

# %%
# checking wether b is tuple or not(it is tuple or not)

# %%
isinstance(b, tuple)
# Out:
# True

# %%
# string into tuple

# %%
k = "Hello World!"

# %%
k
# Out:
# 'Hello World!'

# %%
m=tuple(k)

# %%
m
# Out:
# ('H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!')

# %%
len(k)
# Out:
# 12

# %%
len(m)
# Out:
# 12

# %%
isinstance (k,tuple)
# Out:
# False

# %%
isinstance (m,tuple)
# Out:
# True

# %%
print("strng")
# Out:
# strng

# %%
a1=5

# %%
b=6

# %%
c=a1+b

# %%
print(c)
# Out:
# 11

# %%
print(a1>b)
# Out:
# False

# %%
print(b>a1)
# Out:
# True

# %%
print("a1=b")
# Out:
# a1=b

# %%
print('a1+b')
# Out:
# a1+b

# %% [markdown]
# ## Dictionary 😃 😃

# %%
pic = {"Bobby" : "Dimple", "Sholay" : "Hema", "Roja" : "Madoo", "3 Idiots" : "Kareena" }

# %%
pic
# Out:
# {'Bobby': 'Dimple', 'Sholay': 'Hema', 'Roja': 'Madoo', '3 Idiots': 'Kareena'}

# %%
#movie name: X axis is key, heroins is on y axis which is value

# %%
pic ["Roja"]
# Out:
# 'Madoo'

# %%
pic ["Bobby"]
# Out:
# 'Dimple'

# %%
# change the value of the key or update 😃

# %%
pic["Sholay"]= "jaya"

# %%
pic
# Out:
# {'Bobby': 'Dimple', 'Sholay': 'jaya', 'Roja': 'Madoo', '3 Idiots': 'Kareena'}

# %%
# now create or add a new pair to the dictonary

# %%
pic["Dangal"]="Sana"

# %%
pic["Sultan"]="Anushka"

# %%
pic
# Out:
# {'Bobby': 'Dimple',
#  'Sholay': 'jaya',
#  'Roja': 'Madoo',
#  '3 Idiots': 'Kareena',
#  'Dangal': 'Sana',
#  'Sultan': 'Anushka'}

# %%
# remove any item, lets remove sultan

# %%
pic.pop("Sultan")
# Out:
# 'Anushka'

# %%
pic
# Out:
# {'Bobby': 'Dimple',
#  'Sholay': 'jaya',
#  'Roja': 'Madoo',
#  '3 Idiots': 'Kareena',
#  'Dangal': 'Sana'}

# %%
# retrive items(entire list), keys(movies name or x axis), values(actors name or y axis)

# %%
pic.items()
# Out:
# dict_items([('Bobby', 'Dimple'), ('Sholay', 'jaya'), ('Roja', 'Madoo'), ('3 Idiots', 'Kareena'), ('Dangal', 'Sana')])

# %%
pic.keys()
# Out:
# dict_keys(['Bobby', 'Sholay', 'Roja', '3 Idiots', 'Dangal'])

# %%
pic.values()
# Out:
# dict_values(['Dimple', 'jaya', 'Madoo', 'Kareena', 'Sana'])

# %%
# removing the last item

# %%
pic.popitem()
# Out:
# ('Dangal', 'Sana')

# %%
pic
# Out:
# {'Bobby': 'Dimple', 'Sholay': 'jaya', 'Roja': 'Madoo', '3 Idiots': 'Kareena'}

# %%
# list of movies

# %%
movies=["Bobby", "Don", "Dangal"]

# %%
movies
# Out:
# ['Bobby', 'Don', 'Dangal']

# %%
# lists, starting with 0(Bobby) 1 is 1974 and so on

# %%
cinema = ["Booby", 1974, "Roja", 1990, "3 Idiots", 2008, ["Dimple", "Rishi"],["Madhoo", "Arvind"],["Kareena", "Aamir"]]

# %%
print(cinema)
# Out:
# ['Booby', 1974, 'Roja', 1990, '3 Idiots', 2008, ['Dimple', 'Rishi'], ['Madhoo', 'Arvind'], ['Kareena', 'Aamir']]

# %%
print(cinema[2])
# Out:
# Roja

# %%
print(cinema[7])
# Out:
# ['Madhoo', 'Arvind']

# %%
print(cinema[6])
# Out:
# ['Dimple', 'Rishi']

# %%
print(cinema[7][0])
# Out:
# Madhoo

# %%
# question: at 7 there is Madhoo and at zero there is bobby... why only madhoo came???

# %%
# Alias assigning one variable's value to another variable.

# %%
d=[5,10,50,100]

# %%
d
# Out:
# [5, 10, 50, 100]

# %%
e=d

# %%
d
# Out:
# [5, 10, 50, 100]

# %%
# to change the value of one cell that is of at zero, in above cells d=e so when d changes e also chnaged

# %%
d[0]=500

# %%
d
# Out:
# [500, 10, 50, 100]

# %%
# clone

# %%
f= d[ : ]

# %%
f
# Out:
# [500, 10, 50, 100]

# %%
d[0]="Awesome"

# %%
d
# Out:
# ['Awesome', 10, 50, 100]

# %%
d[0]="Awesome"

# %%
f
# Out:
# [500, 10, 50, 100]

# %%
# in above cells there is no change in f as f is clone of d and it is not a alias as e

# %%
# sets (finding length and setting values)

# %%
set1 ={"Dimple", "Madhoo", "Kareens", "Tina"}

# %%
set1
# Out:
# {'Dimple', 'Kareens', 'Madhoo', 'Tina'}

# %%
len(set1)
# Out:
# 4

# %%
set2= {11,22,33,22}

# %%
set2
# Out:
# {11, 22, 33}

# %%
len(set2)
# Out:
# 3

# %%
set3={"Dimple", "Tina", 11}

# %%
set3
# Out:
# {11, 'Dimple', 'Tina'}

# %%
len(set3)
# Out:
# 3

# %%
# | is used for union and values(names) repeated in set 1 & set 3 are ignored

# %%
set4= set1 | set3

# %%
set4
# Out:
# {11, 'Dimple', 'Kareens', 'Madhoo', 'Tina'}

# %%
# list into set a

# %%
alist= [11,22,33,22,44]

# %%
alist
# Out:
# [11, 22, 33, 22, 44]

# %%
len(alist)
# Out:
# 5

# %%
aset=set(alist)

# %%
aset
# Out:
# {11, 22, 33, 44}

# %%
# ignoring the duplicate value

# %%
len(aset)
# Out:
# 4

# %%
alist[2]
# Out:
# 33

# %%
# union & intersection of sets

# %%
a={11,22,33}

# %%
a
# Out:
# {11, 22, 33}

# %%
b={12,23,33}

# %%
b
# Out:
# {12, 23, 33}

# %%
a|b
# Out:
# {11, 12, 22, 23, 33}

# %%
# & is used to show that intersection which is common in both sets

# %%
a&b
# Out:
# {33}

# %%
# differencing

# %%
a={11,22,33}

# %%
a
# Out:
# {11, 22, 33}

# %%
b={12,23,33}

# %%
b
# Out:
# {12, 23, 33}

# %%
a-b
# Out:
# {11, 22}

# %%
# in above cell values present in a is - by b, 33 is common in b&a so it is ignored.

# %%
b-a
# Out:
# {12, 23}

# %%
# in above cell values present in b is - by a, 33 is common in a&b so it is ignored.

# %%
# symmetrical difference

# %%
a
# Out:
# {11, 22, 33}

# %%
b
# Out:
# {12, 23, 33}

# %%
a^b
# Out:
# {11, 12, 22, 23}

# %%
b^a
# Out:
# {11, 12, 22, 23}

# %% [markdown]
# #### what happend in above cells ma'am 🥺

# %% [markdown]
#  😴 😴 😴

# %%
print(type(strng))
# Out:
# <class 'str'>
