# %%
import nltk # to installl library and to check which version we have
nltk.__version__
# Out:
# '3.5'

# %%
#nltk.download('gutenberg')
#nltk.download('genesis')

# %%
#nltk.download('inaugural')

# %%
#nltk.download('nps_chat')

# %%
#nltk.download('webtext')

# %%
#nltk.download('treebank')

# %%
from nltk.book import* #to import all the book content from nltk

# %%
text6 #name of the books present in book lib
# Out:
# <Text: Monty Python and the Holy Grail>

# %%
text6.similar('king') #function of nltk to explore the content of the book to analysis after import--
#show the word that represent king
# Out:
# then clop arthur i son knights will lord yes well are that please oh
# if fine walk look did eh

# %%
text2.similar('Sense')
# Out:
# sister that side as opinion mother means time marianne wish want part
# sweetness resolution and family property manner life but

# %%
text6.concordance('King') #occurance of the word/phrase you have written,analysis of linguistics,
# Out:
# Displaying 25 of 38 matches:
# CENE 1 : [ wind ] [ clop clop clop ] KING ARTHUR : Whoa there ! [ clop clop cl
# ragon , from the castle of Camelot . King of the Britons , defeator of the Sax
#  CART - MASTER : I dunno . Must be a king . CUSTOMER : Why ? CART - MASTER : H
#  all over him . SCENE 3 : [ thud ] [ King Arthur music ] [ thud thud thud ] [
#  Arthur music ] [ thud thud thud ] [ King Arthur music stops ] ARTHUR : Old wo
# e an inferior ! ARTHUR : Well , I am king ! DENNIS : Oh king , eh , very nice
# HUR : Well , I am king ! DENNIS : Oh king , eh , very nice . And how d ' you g
# o you do , good lady . I am Arthur , King of the Britons . Who ' s castle is t
# s . Who ' s castle is that ? WOMAN : King of the who ? ARTHUR : The Britons .
# . We are all Britons , and I am your king . WOMAN : I didn ' t know we had a k
# g . WOMAN : I didn ' t know we had a king . I thought we were an autonomous co
# ink he is ? Heh . ARTHUR : I am your king ! WOMAN : Well , I didn ' t vote for
# ...

# %%
sents()
# Out:
# sent1: Call me Ishmael .
# sent2: The family of Dashwood had long been settled in Sussex .
# sent3: In the beginning God created the heaven and the earth .
# sent4: Fellow - Citizens of the Senate and of the House of Representatives :
# sent5: I have a problem with people PMing me to lol JOIN
# sent6: SCENE 1 : [ wind ] [ clop clop clop ] KING ARTHUR : Whoa there !
# sent7: Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# sent8: 25 SEXY MALE , seeks attrac older single lady , for discreet encounters .
# sent9: THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .

# %%
text3.concordance('lived')
# Out:
# Displaying 25 of 38 matches:
# ay when they were created . And Adam lived an hundred and thirty years , and be
# ughters : And all the days that Adam lived were nine hundred and thirty yea and
# nd thirty yea and he died . And Seth lived an hundred and five years , and bega
# ve years , and begat Enos : And Seth lived after he begat Enos eight hundred an
# welve years : and he died . And Enos lived ninety years , and begat Cainan : An
#  years , and begat Cainan : And Enos lived after he begat Cainan eight hundred
# ive years : and he died . And Cainan lived seventy years and begat Mahalaleel :
# rs and begat Mahalaleel : And Cainan lived after he begat Mahalaleel eight hund
# years : and he died . And Mahalaleel lived sixty and five years , and begat Jar
# s , and begat Jared : And Mahalaleel lived after he begat Jared eight hundred a
# and five yea and he died . And Jared lived an hundred sixty and two years , and
# ...

# %%
text3.common_contexts(['earth', 'heaven'])
# Out:
# the_, the_; the_be the_and the_to

# %%
#text3.collocations() #related with pair of words,for ex: if a word "she siad " is beimg repeated again&again this will become pair.
text3.collocation_list()
# Out:
# [('said', 'unto'),
#  ('pray', 'thee'),
#  ('thou', 'shalt'),
#  ('thou', 'hast'),
#  ('thy', 'seed'),
#  ('years', 'old'),
#  ('spake', 'unto'),
#  ('thou', 'art'),
#  ('LORD', 'God'),
#  ('every', 'living'),
#  ('God', 'hath'),
#  ('begat', 'sons'),
#  ('seven', 'years'),
#  ('shalt', 'thou'),
#  ('little', 'ones'),
#  ('living', 'creature'),
#  ('creeping', 'thing'),
#  ('savoury', 'meat'),
#  ('thirty', 'years'),
#  ('every', 'beast')]

# %%
text6.generate(6) #generate any random 6 words from the text6
# Out:
# Building ngram index...
# Saint Aauuuves in Cornwall ? '
# "Saint Aauuuves in Cornwall ? '"

# %%
len(text3)
# Out:
# 44764

# %%
from nltk import lm #language modeling(LM) Train model and test model it evavulate and train your data and generate text,
#on the basis of clases. generation of vocabulary. ngram.
#bygram: to check the possibilty of the word pair

help(lm)
# Out:
# Help on package nltk.lm in nltk:
#
# NAME
#     nltk.lm
#
# DESCRIPTION
#     NLTK Language Modeling Module.
#     ------------------------------
#
#     Currently this module covers only ngram language models, but it should be easy
#     to extend to neural models.
#
#
#     Preparing Data
# ...
#
#     Before we train our ngram models it is necessary to make sure the data we put in
#     them is in the right format.
#     Let's say we have a text that is a list of sentences, where each sentence is
#     a list of strings. For simplicity we just consider a text consisting of
#     characters instead of words.
#
#         >>> text = [['a', 'b', 'c'], ['a', 'c', 'd', 'c', 'e', 'f']]
#
#     If we want to train a bigram model, we need to turn this text into bigrams.
#     Here's what the first sentence of our text would look like if we use a function
#     from NLTK for this.
#
#         >>> from nltk.util import bigrams
#         >>> list(bigrams(text[0]))
# ...

# %%
import nltk

# %%
text = "Hello students, we are studying Parts of Speech Tagging. Lets understand the process of\
            shallow parsing or Chunking. Here were are drawing the tree corresponding to the words \
            and the POS tags based on a set grammer regex patter."
words = nltk.word_tokenize(text)
words
# Out:
# ['Hello',
#  'students',
#  ',',
#  'we',
#  'are',
#  'studying',
#  'Parts',
#  'of',
#  'Speech',
#  'Tagging',
#  '.',
#  'Lets',
#  'understand',
#  'the',
#  'process',
#  'of',
#  'shallow',
#  'parsing',
#  'or',
#  'Chunking',
#  '.',
#  'Here',
#  'were',
#  'are',
#  'drawing',
#  'the',
#  'tree',
#  'corresponding',
#  'to',
#  'the',
#  'words',
#  'and',
#  'the',
#  'POS',
#  'tags',
#  'based',
#  'on',
#  'a',
#  'set',
#  'grammer',
#  'regex',
#  'patter',
#  '.']

# %%
# nltk.download('averaged_perceptron_tagger')

# %%
tags = nltk.pos_tag(words) #in which part of speech this particular word comes
tags
# Out:
# [('Hello', 'NNP'),
#  ('students', 'NNS'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('are', 'VBP'),
#  ('studying', 'VBG'),
#  ('Parts', 'NNS'),
#  ('of', 'IN'),
#  ('Speech', 'NNP'),
#  ('Tagging', 'NNP'),
#  ('.', '.'),
#  ('Lets', 'NNS'),
#  ('understand', 'VBP'),
#  ('the', 'DT'),
#  ('process', 'NN'),
#  ('of', 'IN'),
#  ('shallow', 'JJ'),
#  ('parsing', 'NN'),
#  ('or', 'CC'),
#  ('Chunking', 'NNP'),
#  ('.', '.'),
#  ('Here', 'RB'),
#  ('were', 'VBD'),
#  ('are', 'VBP'),
#  ('drawing', 'VBG'),
#  ('the', 'DT'),
#  ('tree', 'NN'),
#  ('corresponding', 'VBG'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('words', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('POS', 'NNP'),
#  ('tags', 'NNS'),
#  ('based', 'VBN'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('set', 'NN'),
#  ('grammer', 'NN'),
#  ('regex', 'NN'),
#  ('patter', 'NN'),
#  ('.', '.')]

# %%
grammar = (''' NP: {<DT><JJ><NN>} ''') #to compare one 
#word with other POS as one word can comes under different POS

# %%
'''chunk_par = nltk.RegexpParser(grammar) #create a new object parser and to decide 
which grammar is used where tree = chunk_par.parse(tags) #tag different part 
of speech and group same chunks with the help of parse
tree.draw()'''
# Out:
# 'chunk_par = nltk.RegexpParser(grammar) #create a new object parser and to decide \nwhich grammar is used where tree = chunk_par.parse(tags) #tag different part \nof speech and group same chunks with the help of parse\ntree.draw()'

# %%
text3
# Out:
# <Text: The Book of Genesis>

# %%
freq = FreqDist(text3)

# %%
freq
# Out:
# FreqDist({',': 3681, 'and': 2428, 'the': 2411, 'of': 1358, '.': 1315, 'And': 1250, 'his': 651, 'he': 648, 'to': 611, ';': 605, ...})

# %%
print(freq)
# Out:
# <FreqDist with 2789 samples and 44764 outcomes>

# %%
freq.most_common(50) #to print freq of most used 50 word
# Out:
# [(',', 3681),
#  ('and', 2428),
#  ('the', 2411),
#  ('of', 1358),
#  ('.', 1315),
#  ('And', 1250),
#  ('his', 651),
#  ('he', 648),
#  ('to', 611),
#  (';', 605),
#  ('unto', 590),
#  ('in', 588),
#  ('that', 509),
#  ('I', 484),
#  ('said', 476),
#  ('him', 387),
#  ('a', 342),
#  ('my', 325),
#  ('was', 317),
#  ('for', 297),
#  ('it', 290),
#  ('with', 289),
#  ('me', 282),
#  ('thou', 272),
#  ("'", 268),
#  ('is', 267),
#  ('thy', 267),
#  ('s', 263),
#  ('thee', 257),
#  ('be', 254),
#  ('shall', 253),
#  ('they', 249),
#  ('all', 245),
#  (':', 238),
#  ('God', 231),
#  ('them', 230),
#  ('not', 224),
#  ('which', 198),
#  ('father', 198),
#  ('will', 195),
#  ('land', 184),
#  ('Jacob', 179),
#  ('came', 177),
#  ('her', 173),
#  ('LORD', 166),
#  ('were', 163),
#  ('she', 161),
#  ('from', 157),
#  ('Joseph', 157),
#  ('their', 153)]

# %%
freq['and'] #to print the freq of "and"
# Out:
# 2428

# %%
freq.plot(20, cumulative = True)

# %%
freq.plot(20)

# %%
freq.tabulate() #display the freq of the word in table form
# Out:
#               ,             and             the              of               .             And             his              he              to               ;            unto              in            that               I            said             him               a              my             was             for              it            with              me            thou               '              is             thy               s            thee              be           shall            they             all               :             God            them             not           which          father            will            land           Jacob            came             her            LORD            were             she            from          Joseph           their             son               ?            sons            upon             had            have         Abraham            this              up             are           there             man       
# ...

# %%
freq.N() #total count of freq
# Out:
# 44764

# %%
freq.max()
# Out:
# ','

# %%
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
[i for i in sent3 if len(i) > 8]
# Out:
# ['beginning']

# %%
[i for i in sent3 if len(i) != 3]
# Out:
# ['In', 'beginning', 'created', 'heaven', 'earth', '.']

# %%
[i for i in sent3 if len(i) <= 3]
# Out:
# ['In', 'the', 'God', 'the', 'and', 'the', '.']

# %%
l = []
for i in sent3:
    if((len(i)) == 6):
        l.append(i)
print(l)
print(len(l))
# Out:
# ['heaven']
# 1

# %%
[i for i in sent3 if i.startswith('ea')]
# Out:
# ['earth']

# %%
[i for i in sent3 if i.endswith('ing')]
# Out:
# ['beginning']

# %%
[i for i in text3 if i.isdigit()]
# Out:
# []

# %%
[i for i in sent3 if i.islower()]
# Out:
# ['the', 'beginning', 'created', 'the', 'heaven', 'and', 'the', 'earth']

# %%
sorted(i for i in sent3 if i.islower())
# Out:
# ['and', 'beginning', 'created', 'earth', 'heaven', 'the', 'the', 'the']

# %%
#to print the words which are having alphabets more than 8 in text 3
l = []
for i in text3:
    if(len(i) > 8):
        if(i not in l):
            l.append(i)
            
print(l)
print('============================================================================================') #to divide the l & sorted l
print(sorted(l)) #to sort the output alphabetially
# Out:
# ['beginning', 'firmament', 'gathering', 'abundantly', 'replenish', 'sanctified', 'generations', 'knowledge', 'compasseth', 'Euphrates', 'commanded', 'whatsoever', 'Therefore', 'themselves', 'shouldest', 'conception', 'hearkened', 'Cherubims', 'conceived', 'firstlings', 'countenance', 'henceforth', 'punishment', 'whosoever', 'vengeance', 'sevenfold', 'Methusael', 'Tubalcain', 'instructor', 'artificer', 'appointed', 'daughters', 'Mahalaleel', 'Methuselah', 'concerning', 'wickedness', 'imagination', 'continually', 'repenteth', 'corrupted', 'establish', 'according', 'righteous', 'generation', 'substance', 'hundredth', 'seventeenth', 'fountains', 'increased', 'prevailed', 'exceedingly', 'mountains', 'destroyed', 'remembered', 'restrained', 'decreased', 'twentieth', 'offerings', 'remaineth', 'delivered', 'perpetual', 'generatio', 'everlasting', 'established', 'overspread', 'husbandman', 'uncovered', 'nakedness', 'shoulders', 'wherefore', 'Naphtuhim', 'Pathrusim', 'Philistim', 'Caphtorim', 
# ...

# %%
num = FreqDist(l) #we create a variable num to get the distinct word that only occur once
num
# Out:
# FreqDist({'beginning': 1, 'firmament': 1, 'gathering': 1, 'abundantly': 1, 'replenish': 1, 'sanctified': 1, 'generations': 1, 'knowledge': 1, 'compasseth': 1, 'Euphrates': 1, ...})

# %%
num.plot(50) #to make a graph of the top 50 distinct words that occur once

# %%
list(bigrams(['more', 'done', 'is', 'go', 'gone', 'morning', 'good', 'night', 'than']))
# Out:
# [('more', 'done'),
#  ('done', 'is'),
#  ('is', 'go'),
#  ('go', 'gone'),
#  ('gone', 'morning'),
#  ('morning', 'good'),
#  ('good', 'night'),
#  ('night', 'than')]

# %% [markdown]
# ### give the count of words which are in lower case in text 3

# %%
len(set(word.lower() for word in text3))
# Out:
# 2628

# %%
len(set(word.lower() for word in text3 if word.isalpha()))
# Out:
# 2615

# %%
len(sorted(set(w.lower() for w in text3)))
# Out:
# 2628

# %%
len(sorted(w.lower() for w in set(text3)))
# Out:
# 2789

# %%
demo_set = {1, 1, 1, 2, 2}
demo_set
# Out:
# {1, 2}

# %%
l = [1, 1, 1, 2, 2]
set(l)
# Out:
# {1, 2}

# %%
len(sorted(set(text3)))
# Out:
# 2789

# %%
text_demo = 'HARhar'

# %%
[w.lower() for w in set(text_demo)]
# Out:
# ['h', 'r', 'a', 'a', 'h', 'r']

# %%
set(w.lower() for w in text_demo)
# Out:
# {'a', 'h', 'r'}

# %%
# after

# %%
test_demo = 'NisHAnis'

# %%
[w.lower() for w in set(test_demo)]
# Out:
# ['n', 'a', 'h', 'n', 's', 'i']

# %%
set([w.lower() for w in test_demo])
# Out:
# {'a', 'h', 'i', 'n', 's'}
